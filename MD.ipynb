# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier, GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, recall_score, precision_score

# %%
variable_name = pd.read_csv("Dentistry Dataset.csv")

# %%
import pandas as 
DentistryDataset = pd.read_csv('Dentistry Dataset.csv')
print(DentistryDataset.isnull().sum())
# Out:
#   Cell In[7], line 1
#     import pandas as
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd

# Example DataFrame
data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [10, 20, 30, 40, 50],
    'Target': [0, 1, 0, 1, 0]
}

df = pd.DataFrame(data)

# %%
X = df[['Feature1', 'Feature2']] 
Y = df['Target']

# %%
print("Independent Variables (X):")
print(X)

print("\nDependent Variable (Y):")
print(Y)
# Out:
# Independent Variables (X):
#    Feature1  Feature2
# 0         1        10
# 1         2        20
# 2         3        30
# 3         4        40
# 4         5        50
#
# Dependent Variable (Y):
# 0    0
# 1    1
# 2    0
# 3    1
# 4    0
# Name: Target, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("Training set (X):")
print(X_train)
print("\nTesting set (X):")
print(X_test)
print("\nTraining set (Y):")
print(Y_train)
print("\nTesting set (Y):")
print(Y_test)
# Out:
# Training set (X):
#    Feature1  Feature2
# 4         5        50
# 2         3        30
# 0         1        10
# 3         4        40
#
# Testing set (X):
#    Feature1  Feature2
# 1         2        20
#
# Training set (Y):
# 4    0
# 2    0
# 0    0
# 3    1
# Name: Target, dtype: int64
#
# Testing set (Y):
# 1    1
# Name: Target, dtype: int64

# %%
from sklearn.preprocessing import Normalizer
import pandas as pd
data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data)
X = df[['Feature1', 'Feature2']]

normalizer = Normalizer()
X_normalized = normalizer.fit_transform(X)

X_normalized_df = pd.DataFrame(X_normalized, columns=['Feature1', 'Feature2'])
print("Normalized X:")
print(X_normalized_df)
# Out:
# Normalized X:
#    Feature1  Feature2
# 0  0.099504  0.995037
# 1  0.099504  0.995037
# 2  0.099504  0.995037
# 3  0.099504  0.995037
# 4  0.099504  0.995037

# %%
from sklearn.model_selection import train_test_split
X = df_reduced  # Independent variables
Y = pd.Series([0, 1, 0, 1, 0], name='Target')
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
print("Training set:")
print(X_train)
print("Testing set:")
print(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X = df_reduced  # Independent variables
#       3 Y = pd.Series([0, 1, 0, 1, 0], name='Target')
#       4 X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
#
# NameError: name 'df_reduced' is not defined

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score

# Initialize models
log_reg = LogisticRegression()
dec_tree = DecisionTreeClassifier()
rand_forest = RandomForestClassifier()
xgb_clf = xgb.XGBClassifier()

# Fit models
log_reg.fit(X_train, Y_train)
dec_tree.fit(X_train, Y_train)
rand_forest.fit(X_train, Y_train)
xgb_clf.fit(X_train, Y_train)

# Predict on test set
log_reg_preds = log_reg.predict(X_test)
dec_tree_preds = dec_tree.predict(X_test)
rand_forest_preds = rand_forest.predict(X_test)
xgb_clf_preds = xgb_clf.predict(X_test)

# Evaluate models
print("Logistic Regression accuracy:", accuracy_score(Y_test, log_reg_preds))
print("Decision Tree accuracy:", accuracy_score(Y_test, dec_tree_preds))
print("Random Forest accuracy:", accuracy_score(Y_test, rand_forest_preds))
print("XGBoost accuracy:", accuracy_score(Y_test, xgb_clf_preds))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 4
#       2 from sklearn.tree import DecisionTreeClassifier
#       3 from sklearn.ensemble import RandomForestClassifier
# ----> 4 import xgboost as xgb
#       5 from sklearn.metrics import accuracy_score
#       7 # Initialize models
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
import pandas as pd

data = {
    'Feature1': [1, 2, 3, 4, 5],
    'Feature2': [10, 20, 30, 40, 50],
    'Feature3': [10, 20, 30, 40, 50],
    'Feature4': [1, 2, 3, 4, 5]
}

df = pd.DataFrame(data)
corr_matrix = df.corr().abs()

threshold = 0.9
to_drop = [column for column in corr_matrix.columns if any(corr_matrix[column] > threshold)]
df_reduced = df.drop(columns=to_drop)
print("Reduced DataFrame:")
print(df_reduced)
# Out:
# Reduced DataFrame:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
pip install scikit-learn matplotlib xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/124.9 MB 544.7 kB/s eta 0:03:50
#    ---------------------------------------- 0.1/124.9 MB 573.4 kB/s eta 0:03:38
#    ---------------------------------------- 0.1/124.9 MB 708.1 kB/s eta 0:02:57
#    ---------------------------------------- 0.2/124.9 MB 817.0 kB/s eta 0:02:33
#    ---------------------------------------- 0.2/124.9 MB 731.4 kB/s eta 0:02:51
#    ---------------------------------------- 0.3/124.9 MB 840.4 kB/s eta 0:02:29
#    ---------------------------------------- 0.4/124.9 MB 928.4 kB/s eta 0:02:15
#    ---------------------------------------- 0.4/124.9 MB 970.6 kB/s eta 0:02:09
#    ---------------------------------------- 0.5/124.9 MB 1.1 MB/s eta 0:01:54
#    ---------------------------------------- 0.6/124.9 MB 1.2 MB/s eta 0:01:45
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, roc_curve, roc_auc_score, ConfusionMatrixDisplay
import seaborn as sns

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay

conf_matrix = confusion_matrix(Y_test, log_reg_preds)
accuracy = accuracy_score(Y_test, log_reg_preds)
print("Confusion Matrix:")
print(conf_matrix)
print(f"Accuracy: {accuracy:.2f}")
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix, display_labels=['Class 0', 'Class 1'])
disp.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Logistic Regression")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 from sklearn.metrics import confusion_matrix, accuracy_score, ConfusionMatrixDisplay
# ----> 3 conf_matrix = confusion_matrix(Y_test, log_reg_preds)
#       4 accuracy = accuracy_score(Y_test, log_reg_preds)
#       5 print("Confusion Matrix:")
#
# NameError: name 'log_reg_preds' is not defined

# %%
from sklearn.metrics import roc_curve, roc_auc_score
fpr, tpr, _ = roc_curve(Y_test, log_reg.predict_proba(X_test)[:,1])
roc_auc = roc_auc_score(Y_test, log_reg.predict_proba(X_test)[:,1])
print(f"ROC AUC: {roc_auc:.2f}")
plt.figure()
plt.plot(fpr, tpr, color='blue', lw=2, label=f'Logistic Regression (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
conf_matrix_rf = confusion_matrix(Y_test, rand_forest_preds)
accuracy_rf = accuracy_score(Y_test, rand_forest_preds)
print("Confusion Matrix for Random Forest:")
print(conf_matrix_rf)
print(f"Accuracy: {accuracy_rf:.2f}")
disp_rf = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_rf, display_labels=['Class 0', 'Class 1'])
disp_rf.plot(cmap=plt.cm.Blues)
plt.title("Confusion Matrix for Random Forest")
plt.show()
fpr_rf, tpr_rf, _ = roc_curve(Y_test, rand_forest.predict_proba(X_test)[:,1])
roc_auc_rf = roc_auc_score(Y_test, rand_forest.predict_proba(X_test)[:,1])
print(f"ROC AUC for Random Forest: {roc_auc_rf:.2f}")
plt.figure()
plt.plot(fpr_rf, tpr_rf, color='green', lw=2, label=f'Random Forest (area = {roc_auc_rf:.2f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 conf_matrix_rf = confusion_matrix(Y_test, rand_forest_preds)
#       2 accuracy_rf = accuracy_score(Y_test, rand_forest_preds)
#       3 print("Confusion Matrix for Random Forest:")
#
# NameError: name 'rand_forest_preds' is not defined
